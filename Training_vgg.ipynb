# %% [markdown]
# ## Colab Stuff
#
# It's highly recommended to download the dataset first to your drive and work on Google Colab to save your time (and your local machine too:)))

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/My Drive'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive

# %% [markdown]
# ## Datasets
#
# The official website of `PASCAL VOC` dataset is not working. So, you will need to search for a new way:
# 1. This is an alternative website which we used: [https://deepai.org/dataset/pascal-voc](https://deepai.org/dataset/pascal-voc)
# 2. Use our shared version from [Google Drive](https://drive.google.com/drive/folders/1wyB3XcD8EhiZI1BZYZ5SawG-DOwZzBV_?usp=sharing) in case the alternative website isn't available too.
#
# P.S. Our drive folder contains only `PASCAL VOC 2007`. If you need a compressed folder for `PASCAL VOC 2012`, you can easily find it [here](https://drive.google.com/file/d/1XU7qwUVnV2S_iiWfb4DEmoxjbnQJxpHE/view?usp=sharing://) on our Google Drive too :)

# %% [markdown]
# ## Reading Dataset

# %%
# !pip install tqdm --upgrade
# Out:
# Requirement already satisfied: tqdm in e:\anaconda\anaconda\lib\site-packages (4.32.1)
# Collecting tqdm
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: colorama in e:\anaconda\anaconda\lib\site-packages (from tqdm) (0.4.4)
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.32.1
#     Uninstalling tqdm-4.32.1:
#       Successfully uninstalled tqdm-4.32.1
# Successfully installed tqdm-4.64.0

# %%
from utils.agent import *
from utils.dataset import read_voc_dataset
from IPython.display import clear_output
import tqdm.notebook as tq
# %reload_ext autoreload
# %autoreload 2

train_loader2007, _ = read_voc_dataset(path="." ,year='2007')
# Out:
# Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar to .\VOCtrainval_06-Nov-2007.tar
# HBox(children=(IntProgress(value=0, max=460032000), HTML(value='')))
# Extracting .\VOCtrainval_06-Nov-2007.tar to .
# Using downloaded and verified file: .\VOCtrainval_06-Nov-2007.tar
# Extracting .\VOCtrainval_06-Nov-2007.tar to .

# %% [markdown]
# ## Dataset Organization

# %%
#put datalist in list in case of combination of different datasets
#For example: [train_loader2007, train_loader2012]
datasets_per_class = sort_class_extract([train_loader2007])
# Out:
#   0%|          | 0/2501 [00:00<?, ?it/s]

# %% [markdown]
# ## Training Loop

# %%
for i in tq.tqdm(range(len(classes))):
    classe = classes[i]
    print("Classe "+str(classe)+"...")
    agent = Agent(classe, alpha=0.2, num_episodes=15, load=False, model_name='vgg16')
    agent.train(datasets_per_class[classe])
    del agent
    torch.cuda.empty_cache()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Classe cat...
# Episode 0
# C:\Users\msi-\Desktop\22Spring_BDT\CV\project\Active-Object-Localization-main\utils\agent.py:183: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   non_final_next_states = Variable(torch.cat(next_states), volatile=True).type(Tensor)
# C:\Users\msi-\Desktop\22Spring_BDT\CV\project\Active-Object-Localization-main\utils\agent.py:201: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#